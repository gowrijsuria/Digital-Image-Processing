# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

im = cv2.imread('../input/bricks.jpg',0)
    
h,w = im.shape
for nx in range(1,11):
    ny = nx
    sampled_im = im[0::nx,0::ny]
    plt.figure(figsize=(10,10))
    plt.subplot(121)
    plt.imshow(im,'gray')
    plt.subplot(122)
    plt.imshow(sampled_im,'gray')
    plt.title('{}'.format(nx))
    plt.show()

# %%
blurred_im = gaussian_filt(im,10)
for nx_blur in range(1,11):        
    ny_blur = nx_blur

    sampled_im_blur = blurred_im[0::nx_blur,0::ny_blur]
    plt.figure(figsize=(15,15))
    plt.subplot(131)
    plt.imshow(im,'gray')
    plt.subplot(132)
    plt.imshow(blurred_im,'gray')
    plt.subplot(133)
    plt.imshow(sampled_im_blur,'gray')
    plt.title('{}'.format(nx_blur))
    plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:34: ComplexWarning: Casting complex values to real discards the imaginary part

# %% [markdown]
# Nyquist rate is 1/nx or 1/ny for the image
#
# Nyquist rate = 1/5 for bricks
#
# Nyquist rate = 1/7 for blurred bricks
